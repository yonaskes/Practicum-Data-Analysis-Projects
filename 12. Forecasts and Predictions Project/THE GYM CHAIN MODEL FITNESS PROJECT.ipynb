# %% [markdown]
# Hello Yonas!
#
# My name is Olga. I'm happy to review your project today.
#
# When I will see mistake at the first time, I will just point it out. I let you find it and fix it by yourself. I'm trying to prepare you to work as an Data Analyst. SO, at a real job, your team lead will do the same. But if you can't handle this task yet, I will give you a more accurate hint at the next iteration.
#
# You will find my comments below - **please do not move, modify or delete them**.
#
# You can find my comments in green, yellow or red boxes like this:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Success. Everything is done succesfully.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Remarks. Some recommendations.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
#
# </div>
#
# You can answer me by using this:
#
# <div class="alert alert-block alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
#
# Hello Olga, glad to hear you again. How have you been? I tried repeatedly many times it is working on my side. It is loading. I didn't get any error or problem but it takes some time.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Yonas, thank you so much for the project. It is correct before cell 35. This cell cannot loading. Could you check it?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Overallv reviewer's comment</b> <a class="tocSkip"></a>
#
# Yonas, thank you for sending your project. You've done a really good job on it!
#
# While there's room for improvement, on the whole, your project is impressive good. I like code style - very high level! Thank you for your detailed conclusions. They are wonderful. You did a great job! I am really impressed!
#
#
# <span class="text-danger">There is one thing that need to be corrected in your project. There is minor issue that are easy to fix. I wrote comment. Could you check it?</span>
#
# Every issue with our code is a chance for us to learn something new.
#
# Good luck! :)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Oberall reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Hi Yonas! We need a little bit more work with some parts. Please, check my comments.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Overall reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Hi Yonas!
# </div>

# %% [markdown]
# # PROJECT DESCRIPTION

# %% [markdown]
# # THE GYM CHAIN MODEL FITNESS

# %% [markdown]
# The gym chain Model Fitness is developing a customer interaction strategy based on analytical data.
#
# One of the most common problems gyms and other services face is customer churn. How do you know if a customer is no longer with you? You can calculate churn based on people who get rid of their accounts or don't renew their contracts. However, sometimes it's not obvious that a client has left: they may walk out on tiptoes.
#
# Churn indicators vary from field to field. If a user buys from an online store rarely but regularly, you can't say they're a runaway. But if for two weeks they haven't opened a channel that's updated daily, that's a reason to worry: your follower might have gotten bored and left you.
#
# For a gym, it makes sense to say a customer has left if they don't come for a month. Of course, it's possible they're in Cancun and will resume their visits when they return, but's that's not a typical case. Usually, if a customer joins, comes a few times, then disappears, they're unlikely to come back.
#
# In order to fight churn, Model Fitness has digitized a number of its customer profiles. Your task is to analyze them and come up with a customer retention strategy.

# %% [markdown]
# **You should:**
#
#
#    * Learn to predict the probability of churn (for the upcoming month) for each customer
#
#
#    * Draw up typical user portraits: select the most outstanding groups and describe their main features
#
#
#
#    * Analyze the factors that impact churn most
#
#
#    * Draw basic conclusions and develop recommendations on how to improve customer service:
#
#
#       * Identify target groups
#
#       * Suggest measures to cut churn
#
#       * Describe any other patterns you see with respect to interaction with customers

# %% [markdown]
# # Description of the data

# %% [markdown]
# Model Fitness provided you with CSV files containing data on churn for a given month and information on the month preceding it. The dataset includes the following fields:
#
#
# * **'Churn' — the fact of churn for the month in question**
#
#
# * **Current dataset fields:**
#
#    * **User data for the preceding month**
#
#           * 'gender'
#           * 'Near_Location' — whether the user lives or works in the neighborhood where the gym is located
#           * 'Partner' — whether the user is an employee of a partner company (the gym has partner companies whose employees get discounts; in those cases the gym stores information on customers' employers)
#           * Promo_friends — whether the user originally signed up through a "bring a friend" offer (they used a friend's promo code when paying for their first membership)
#           * 'Phone' — whether the user provided their phone number
#           * 'Age'
#           * 'Lifetime' — the time (in months) since the customer first came to the gym
#
# * **Data from the log of visits and purchases and data on current membership status**
#
#
#      * 'Contract_period' — 1 month, 3 months, 6 months, or 1 year
#      * 'Month_to_end_contract' — the months remaining until the contract expires
#      * 'Group_visits' — whether the user takes part in group sessions
#      * 'Avg_class_frequency_total' — average frequency of visits per week over the customer's lifetime
#      * 'Avg_class_frequency_current_month' — average frequency of visits per week over the preceding month
#     * 'Avg_additional_charges_total' — the total amount of money spent on other gym services: cafe, athletic goods, cosmetics, massages, etc.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Great start with an introduction!
# </div>

# %% [markdown]
# # Instructions for completing the project

# %% [markdown]
# # Step 1. Download the data

# %% [markdown]
# **File path: /datasets/gym_churn_us.csv Download dataset**

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import math as mth
from scipy import stats as st

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, precision_score, recall_score

from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')

# %%
try:
    data = pd.read_csv('/gym_churn_us.csv')
except:    
    data = pd.read_csv('/datasets/gym_churn_us.csv')
finally:
    print('Try to read files')
       
data.head()
# Out:
# Try to read files
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
# ...

# %%
# To know the number of columns and rows in the DataFrame
data.shape
# Out:
# (4000, 14)

# %%
# Get information about the DataFrame
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %%
# To check whether column's name are written in appropriate way
data.columns
# Out:
# Index(['gender', 'Near_Location', 'Partner', 'Promo_friends', 'Phone',
#        'Contract_period', 'Group_visits', 'Age',
#        'Avg_additional_charges_total', 'Month_to_end_contract', 'Lifetime',
#        'Avg_class_frequency_total', 'Avg_class_frequency_current_month',
#        'Churn'],
#       dtype='object')

# %%
# Checking duplicates in the DataFrame
data.duplicated().sum()
# Out:
# 0

# %%
# To check if there are unique values
data['gender'].unique()
# Out:
# array([1, 0])

# %%
# To check if there are unique values
data['Churn'].unique()
# Out:
# array([0, 1])

# %%
# Convert all column names to lowercase
data.columns = data.columns.str.lower()

# %%
# Checking the columns name if they are re-written in a convenient way
data.columns
# Out:
# Index(['gender', 'near_location', 'partner', 'promo_friends', 'phone',
#        'contract_period', 'group_visits', 'age',
#        'avg_additional_charges_total', 'month_to_end_contract', 'lifetime',
#        'avg_class_frequency_total', 'avg_class_frequency_current_month',
#        'churn'],
#       dtype='object')

# %%
# Get information about the DataFrame
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   month_to_end_contract              4000 non-null   float64
#  10  lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# So, we have basic information about our dataset.
# </div>

# %% [markdown]
# # Step 2. Carry out exploratory data analysis (EDA)

# %% [markdown]
# * Look at the dataset: does it contain any missing features? Study the mean values and standard deviation (use the describe() method).
#
#
# * Look at the mean feature values in two groups: for those who left (churn) and for those who stayed (use the groupby() method).
#
#
# * Plot bar histograms and feature distributions for those who left (churn) and those who stayed.
#
#
# * Build a correlation matrix and display it.

# %% [markdown]
# **Look at the dataset: does it contain any missing features? Study the mean values and standard deviation (use the describe() method).**

# %%
#looking at the dataset
data.head()
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# ...

# %%
# To confirm the missing values of the DataFrame
data.isna().sum()
# Out:
# gender                               0
# near_location                        0
# partner                              0
# promo_friends                        0
# phone                                0
# contract_period                      0
# group_visits                         0
# age                                  0
# avg_additional_charges_total         0
# month_to_end_contract                0
# lifetime                             0
# avg_class_frequency_total            0
# avg_class_frequency_current_month    0
# churn                                0
# dtype: int64

# %%
# To get the percentile information of the columns in the dataframe
data.isnull().sum()*100/len(data)
# Out:
# gender                               0.0
# near_location                        0.0
# partner                              0.0
# promo_friends                        0.0
# phone                                0.0
# contract_period                      0.0
# group_visits                         0.0
# age                                  0.0
# avg_additional_charges_total         0.0
# month_to_end_contract                0.0
# lifetime                             0.0
# avg_class_frequency_total            0.0
# avg_class_frequency_current_month    0.0
# churn                                0.0
# dtype: float64

# %%
# To get the percentile information of the columns in the dataframe
mis_values = data.isnull().sum().to_frame('missing_values')
mis_values['%'] = round(data.isnull().sum()*100/len(data), 3)
mis_values['%']
# Out:
# gender                               0.0
# near_location                        0.0
# partner                              0.0
# promo_friends                        0.0
# phone                                0.0
# contract_period                      0.0
# group_visits                         0.0
# age                                  0.0
# avg_additional_charges_total         0.0
# month_to_end_contract                0.0
# lifetime                             0.0
# avg_class_frequency_total            0.0
# avg_class_frequency_current_month    0.0
# churn                                0.0
# Name: %, dtype: float64

# %%
mis_values.sort_values(by='%', ascending = False)
# Out:
#                                    missing_values    %
# gender                                          0  0.0
# near_location                                   0  0.0
# partner                                         0  0.0
# promo_friends                                   0  0.0
# phone                                           0  0.0
# contract_period                                 0  0.0
# group_visits                                    0  0.0
# age                                             0  0.0
# avg_additional_charges_total                    0  0.0
# month_to_end_contract                           0  0.0
# lifetime                                        0  0.0
# avg_class_frequency_total                       0  0.0
# avg_class_frequency_current_month               0  0.0
# churn                                           0  0.0

# %%
# !python -m pip install -U sidetable
import sidetable

# %%
# Second way of getting the missing values percentage
data.stb.missing(style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_7242b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >missing</th>        <th class="col_heading level0 col1" >total</th>        <th class="col_heading level0 col2" >percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7242b_level0_row0" class="row_heading level0 row0" >gender</th>
#                         <td id="T_7242b_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_7242b_row0_col1" class="data row0 col1" >4,000</td>
#                         <td id="T_7242b_row0_col2" class="data row0 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_7242b_level0_row1" class="row_heading level0 row1" >near_location</th>
#                         <td id="T_7242b_row1_col0" class="data row1 col0" >0</td>
# ...

# %%
# To get information about statistical character of the DataFrame
data.describe()
# Out:
#             gender  near_location      partner  promo_friends        phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        contract_period  group_visits          age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %%
# To get information about statistical character of the DataFrame
data.describe().T
# Out:
#                                     count        mean        std        min  \
# gender                             4000.0    0.510250   0.499957   0.000000
# near_location                      4000.0    0.845250   0.361711   0.000000
# partner                            4000.0    0.486750   0.499887   0.000000
# promo_friends                      4000.0    0.308500   0.461932   0.000000
# phone                              4000.0    0.903500   0.295313   0.000000
# contract_period                    4000.0    4.681250   4.549706   1.000000
# group_visits                       4000.0    0.412250   0.492301   0.000000
# age                                4000.0   29.184250   3.258367  18.000000
# avg_additional_charges_total       4000.0  146.943728  96.355602   0.148205
# month_to_end_contract              4000.0    4.322750   4.191297   1.000000
# lifetime                           4000.0    3.724750   3.749267   0.000000
# ...

# %% [markdown]
# **Conclusion**
#
#
# * There are 14 columns and 4000 rows of DataFrame.
# * There are no missing values.
# * There are no duplicates in the DataFrame.
# * Almost equal number of Mans and Womans.
# * The averae age of the customers is around 29.12 years.
# * The minimum and maximum age of the ustomers are 18 and 41 years respectively.
# * 48.68%, almost half of the gym are employees of a partner company who have discont program.
# * 84.53% of the gym customers live or work in the neighborhood of the gym.
# * 30.85% of the customers originally signed up through a "bring a friend" offer.
# * 90.4% of the customers provided their phone numbers.
# * The average contract period of customers is 4.68 months.
# * 41.22% of the customers takes part in group sessions.
# * The average lifetime of customers is 3.7 months.
# * average frequency of visits per week over the customer's lifetime 1.86.
# * average frequency of visits per week over the preceding month is 1.76.
# * The total amount of money spent on other gym services: cafe, athletic goods, cosmetics, massages, etc. is 146.94 dollars
# * The fact of churn for the month in question is 26.5%.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Thank you for the details!
# </div>

# %% [markdown]
# **Look at the mean feature values in two groups: for those who left (churn) and for those who stayed (use the groupby() method).**

# %%
data.groupby(['churn']).mean()
# Out:
#          gender  near_location   partner  promo_friends     phone  \
# churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        contract_period  group_visits        age  avg_additional_charges_total  \
# churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        month_to_end_contract  lifetime  avg_class_frequency_total  \
# churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        avg_class_frequency_current_month
# churn
# 0                               2.027882
# 1                               1.044546

# %%
data.groupby(['churn']).mean().T
# Out:
# churn                                       0           1
# gender                               0.510037    0.510839
# near_location                        0.873086    0.768143
# partner                              0.534195    0.355325
# promo_friends                        0.353522    0.183789
# phone                                0.903709    0.902922
# contract_period                      5.747193    1.728558
# group_visits                         0.464103    0.268615
# age                                 29.976523   26.989632
# avg_additional_charges_total       158.445715  115.082899
# month_to_end_contract                5.283089    1.662582
# lifetime                             4.711807    0.990575
# avg_class_frequency_total            2.024876    1.474995
# avg_class_frequency_current_month    2.027882    1.044546

# %%
# To get the churn propertion
(round(data['churn'].value_counts()/data.shape[0], 4).to_frame('Churn Proportions')) * 100
# Out:
#    Churn Proportions
# 0              73.48
# 1              26.52

# %%
(data.groupby(['churn'])['churn'].count()/data.shape[0])*100
# Out:
# churn
# 0    73.475
# 1    26.525
# Name: churn, dtype: float64

# %%
churn1 = data[data.churn ==1]
churn1.describe().T
# Out:
#                                     count        mean        std        min  \
# gender                             1061.0    0.510839   0.500118   0.000000
# near_location                      1061.0    0.768143   0.422217   0.000000
# partner                            1061.0    0.355325   0.478837   0.000000
# promo_friends                      1061.0    0.183789   0.387495   0.000000
# phone                              1061.0    0.902922   0.296204   0.000000
# contract_period                    1061.0    1.728558   2.132371   1.000000
# group_visits                       1061.0    0.268615   0.443448   0.000000
# age                                1061.0   26.989632   2.895163  18.000000
# avg_additional_charges_total       1061.0  115.082899  77.696419   0.148205
# month_to_end_contract              1061.0    1.662582   1.964593   1.000000
# lifetime                           1061.0    0.990575   1.110799   0.000000
# ...

# %%
churn0 = data[data.churn ==0]
churn0.describe().T
# Out:
#                                     count        mean        std        min  \
# gender                             2939.0    0.510037   0.499984   0.000000
# near_location                      2939.0    0.873086   0.332933   0.000000
# partner                            2939.0    0.534195   0.498914   0.000000
# promo_friends                      2939.0    0.353522   0.478144   0.000000
# phone                              2939.0    0.903709   0.295040   0.000000
# contract_period                    2939.0    5.747193   4.716942   1.000000
# group_visits                       2939.0    0.464103   0.498795   0.000000
# age                                2939.0   29.976523   3.009933  19.000000
# avg_additional_charges_total       2939.0  158.445715  99.801599   0.171862
# month_to_end_contract              2939.0    5.283089   4.363522   1.000000
# lifetime                           2939.0    4.711807   3.874780   0.000000
# ...

# %% [markdown]
# **Conclusion**
#
#
# * The total customers in the gym are 4000, out of these 2939 will stay in the gym where as 1061 will leave the gym.
# * The average of genders in who will stay and leave the gym are equal.
# * Customers who live or work close to the gym are less likely to churn.
# * Customers of gym from the partner companies are less likely to churn than the others.
# * Customers of the gym who signed up under the “bring a friend” offer are less likely to churn.
# * Equal number of customers from those who churn and not churn provide their phone number.
# * The contract period for those who would prefer to stay in the gym is 5.75 months where as for those who churn is 1.72 months.
# * More users from those who stay in the gym take part in group session than those who churn, may be because they live and work close to the gmy.
# * The average age of users from those who stay is 29.97 years where as those who churn is 26.99 years.
# * The average total amount of money spent on other gym services: cafe, athletic goods, cosmetics, massages, etc. is more for those who stay in the gym than those who churn.
# * The lifetime for those who stay is 4.71 months where as for those who will churn is 0.99 months.
# * The average frequency of visits per week over the customer's lifetime and the average frequency of visits per week over the preceding month is more than double for who stay than for those who leave or churn.
# * 73% of the customers stay in the gym where as 27% those who will churn.73%

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Thank you for comparison and intresting facts!
#
# </div>

# %% [markdown]
# **Plot bar histograms and feature distributions for those who left (churn) and those who stayed.**

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 1]['avg_additional_charges_total'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 0]['avg_additional_charges_total'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 1]['contract_period'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 0]['contract_period'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 1]['group_visits'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 0]['group_visits'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 1]['month_to_end_contract'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 0]['month_to_end_contract'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 1]['lifetime'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 0]['lifetime'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 1]['avg_class_frequency_total'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 0]['avg_class_frequency_total'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 1]['avg_class_frequency_current_month'],bins = 25);

# %%
plt.figure(figsize = (10,6))
sns.distplot(data[data['churn'] == 0]['avg_class_frequency_current_month'],bins = 25);

# %%
churn1['lifetime'].hist(bins=20)
plt.suptitle("Distribution of churn customers", fontsize=15)
plt.xlabel("Month", fontsize=15)
plt.ylabel("Number of customers left",fontsize=15)
plt.show()

# %%
churn0['lifetime'].hist(bins=20)
plt.suptitle("Distribution of churn customers", fontsize=15)
plt.xlabel("Month", fontsize=15)
plt.ylabel("Number of customers left",fontsize=15)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   month_to_end_contract              4000 non-null   float64
#  10  lifetime                           4000 non-null   int64
# ...

# %%
# Pie charts of features
data['gender'].value_counts(sort = True).plot(
    kind='pie', autopct='%1.1f%%', figsize = (7,7), title = 'Gender Ratio of leaving and Staying Customers in the Gym', shadow=False)
plt.show()

# %%
# Pie charts of features
data['near_location'].value_counts(sort = True).plot(
    kind='pie', autopct='%1.1f%%', figsize = (7,7), title = 'Near Location Ratio of leaving and Staying Customers in the Gym', shadow=False)
plt.show()

# %%
# Pie charts of features
data['partner'].value_counts(sort = True).plot(
    kind='pie', autopct='%1.1f%%', figsize = (7,7), title = 'Partner Ratio of leaving and Staying in the Gym', shadow=False)
plt.show()

# %%
# Pie charts of features
data['promo_friends'].value_counts(sort = True).plot(
    kind='pie', autopct='%1.1f%%', figsize = (7,7), title = 'Promo through Friends Ratio of leaving and Staying Customers in the Gym', shadow=False)
plt.show()

# %%
# Pie charts of features
data['phone'].value_counts(sort = True).plot(
    kind='pie', autopct='%1.1f%%', figsize = (7,7), title = 'Phone Ratio of leaving and Staying Customers in the Gym', shadow=False)
plt.show()

# %%
 # Pie charts of features
data['group_visits'].value_counts(sort = True).plot(
    kind='pie', autopct='%1.1f%%', figsize = (7,7), title = 'Group Visits Ratio of leaving and Staying Customers in the Gym', shadow=False)
plt.show()

# %%
# Pie charts of features
data['churn'].value_counts(sort = True).plot(
    kind='pie', autopct='%1.1f%%', figsize = (7,7), title = 'Churn Ratio of leaving and Staying Customers in the Gym', shadow=False)
plt.show()

# %% [markdown]
# **Conclusion**
#
# * With respect to gender 51% will stay and 49% will leave the gym.
# * With respect to near location 84.5% will stay and 15.5% will leave the gym.
# * With respect to partner 51.3% will stay and 48.7% will leave the gym.
# * With respect to promo friends 69.2% will stay and 30.8% will leave the gym.
# * With respect to phone 90.4% will stay and 9.6% will leave the gym.
# * With respect to group visits 58.8% will stay and 41.2% will leave the gym.
# * With respect to charn 73.5% will stay and 26.5% will leave the gym.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Very good and clear graphs! Also we can create piecharts or something else and show the difference.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Excellent! Now we have information about churn.
# </div>

# %% [markdown]
# **Build a correlation matrix and display it.**

# %%
# Calculate the correlation matrix
corr_matrix = data.corr()
corr_matrix
# Out:
#                                      gender  near_location   partner  \
# gender                             1.000000       0.006699 -0.010463
# near_location                      0.006699       1.000000 -0.005119
# partner                           -0.010463      -0.005119  1.000000
# promo_friends                     -0.005033       0.210964  0.451960
# phone                             -0.008542      -0.015763  0.009970
# contract_period                    0.000502       0.150233  0.306166
# group_visits                       0.017879       0.154728  0.022710
# age                                0.013807       0.058358  0.047480
# avg_additional_charges_total      -0.009334       0.040761  0.022941
# month_to_end_contract             -0.001281       0.143961  0.294632
# lifetime                           0.013579       0.070921  0.061229
# avg_class_frequency_total          0.014620       0.043127  0.024938
# avg_class_frequency_current_month  0.009156       0.062664  0.045561
# ...

# %%
print(corr_matrix)
# Out:
#                                      gender  near_location   partner  \
# gender                             1.000000       0.006699 -0.010463
# near_location                      0.006699       1.000000 -0.005119
# partner                           -0.010463      -0.005119  1.000000
# promo_friends                     -0.005033       0.210964  0.451960
# phone                             -0.008542      -0.015763  0.009970
# contract_period                    0.000502       0.150233  0.306166
# group_visits                       0.017879       0.154728  0.022710
# age                                0.013807       0.058358  0.047480
# avg_additional_charges_total      -0.009334       0.040761  0.022941
# month_to_end_contract             -0.001281       0.143961  0.294632
# lifetime                           0.013579       0.070921  0.061229
# avg_class_frequency_total          0.014620       0.043127  0.024938
# avg_class_frequency_current_month  0.009156       0.062664  0.045561
# ...

# %%
# Plot the heatmap
corrMatrix = data.corr()
fig, ax = plt.subplots(figsize=(15, 9))
sns.heatmap(corrMatrix, annot=True,)
plt.show()

# %% [markdown]
# **Conclusion**
#
#
# * The number of customers who left and stay in the gym are 1061 and 2939 respectively.
# * The correlation matrix shows that there is strong correlation between the 'contract period' and 'month to end contract' features as well as between 'avg_class_frequency_total' and 'avg_class_frequency_current_month' features.
# * The correlation matrix also shows that there is weak correlation of features with 'gender' and 'phone'.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Well done! We have a heatmap for features. Thank you for your excellent conclusions!

# %% [markdown]
# # Step 3. Build a model to predict user churn

# %% [markdown]
# Build a binary classification model for customers where the target feature is the user's leaving next month.

# %% [markdown]
# **Divide the data into train and validation sets using the train_test_split() function.**

# %%
# divide the data into features and a target variable
X = data.drop('churn', axis = 1)
y = data['churn']

# %%
# divide the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# It should be another value in a test size.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Test size should be 20%. Please, change your code a litlle.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Correct!
#
# </div>

# %% [markdown]
# **Train the model on the train set with two methods:**
#
#     * logistic regression
#     * random forest

# %%
# create a StandardScaler object and apply it to the train set
# train the scaler and transform the matrix for the train set
scaler = StandardScaler()
X_train_st = scaler.fit_transform(X_train)

# %%
# apply standardization to the feature matrix for the test set
X_test_st = scaler.transform(X_test)

# %%
# define the model's algorithm 
lr_model = LogisticRegression(random_state=0)

# %%
# train the model
lr_model.fit(X_train_st, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# use the trained model to make forecasts
lr_probabilities = lr_model.predict_proba(X_test_st)[:,1]

# %%
# binary prediction
lr_predictions = lr_model.predict(X_test_st)

# %%
# print all the studied metrics
print('Logistic regression metrics')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, lr_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, lr_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, lr_predictions)))
# Out:
# Logistic regression metrics
# Accuracy: 0.92
# Precision: 0.85
# Recall: 0.83

# %%
# define the algorithm for the new random forest model
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0)

# %%
# train the random forest model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# use the trained model to make predictions
rf_predictions = rf_model.predict(X_test)
rf_probabilities = rf_model.predict_proba(X_test)[:,1]

# %%
# print all the studied metrics
print('Logistic regression metrics')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, rf_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, rf_predictions)))
# Out:
# Logistic regression metrics
# Accuracy: 0.92
# Precision: 0.84
# Recall: 0.82

# %% [markdown]
# **Evaluate accuracy, precision, and recall for both models using the validation data. Use them to compare the models. Which model gave better results?**
#
# Remember to indicate the random_state parameter when dividing data and defining the algorithm.

# %% [markdown]
# **Conclusion**
#
# As it is seen from the result, even though both models provide almost similar metric score, but logistic regression performed a little bit better result in precision and recall metric scores than random forest.

# %%
# Graph of features the leaving customers in the gym
churn1 = data[data.churn == 1]
for i in churn1.columns:
    sns.displot(data= churn1, x = i, height = 4, aspect = 2)
    plt.title('Customers Leaving the Gym')

# %%
# Graph of features the staying customers in the gym
churn0 = data[data.churn == 0]
for i in churn0.columns:
    sns.displot(data= churn0, x = i, height = 4, aspect = 2)
    plt.title('Customers Staying in the Gym')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Please, check the result after changes. Also please, check cells below, result can be different.
#
# Please, add a graph for each feature.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Graphs are good. Please, check results after new test size.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Well done!
# </div>

# %% [markdown]
# # Step 4. Create user clusters

# %% [markdown]
# **Set aside the column with data on churn and identify object (user) clusters:**

# %% [markdown]
# **Standardize the data.**

# %%
# Standardization the data before passing it to the algorithm
scaler = StandardScaler() 
X_sc = scaler.fit_transform(X)

# %% [markdown]
# **Use the linkage() function to build a matrix of distances based on the standardized feature matrix and plot a dendrogram. Note: rendering the dendrogram may take time! Use the resulting graph to estimate the number of clusters you can single out.**

# %%
,# the matrix of distances also helps to determine the optimal number of clusters
linked = linkage(X_sc, method = 'ward')

# %%
# Plot a dendrogram to view the distance between the objects
plt.figure(figsize = (15, 10))  
dendrogram(linked, orientation = 'top')
plt.title('Hierarchical clustering', fontsize = 15)
plt.show()

# %% [markdown]
# **Train the clustering model with the K-means algorithm and predict customer clusters. (Let the number of clusters be n=5, so that it'll be easier to compare your results with those of other students. However, in real life, no one will give you such hints, so you'll have to decide based on the graph from the previous step.)**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Yes, 5 clusters are enough.
# </div>

# %%
# define the k_means model with 5 clusters
km = KMeans(n_clusters = 5, random_state = 0)

# %%
# predict the clusters for observations
# store cluster labels in the field of the dataset
labels = km.fit_predict(X_sc)
data['cluster'] = labels
labels
# Out:
# array([1, 0, 3, ..., 0, 0, 1], dtype=int32)

# %%
data.head().T
# Out:
#                                            0           1           2  \
# gender                              1.000000    0.000000    0.000000
# near_location                       1.000000    1.000000    1.000000
# partner                             1.000000    0.000000    1.000000
# promo_friends                       1.000000    0.000000    0.000000
# phone                               0.000000    1.000000    1.000000
# contract_period                     6.000000   12.000000    1.000000
# group_visits                        1.000000    1.000000    0.000000
# age                                29.000000   31.000000   28.000000
# avg_additional_charges_total       14.227470  113.202938  129.448479
# month_to_end_contract               5.000000   12.000000    1.000000
# lifetime                            3.000000    7.000000    2.000000
# avg_class_frequency_total           0.020398    1.922936    1.859098
# avg_class_frequency_current_month   0.000000    1.910244    1.736502
# ...

# %% [markdown]
# **Look at the mean feature values for clusters. Does anything catch your eye?**

# %%
# print the statistics of the mean feature values per cluster
data.groupby(['cluster']).mean().T
# Out:
# cluster                                     0           1           2  \
# gender                               0.502970    0.522078    0.495050
# near_location                        0.959406    0.862338    0.000000
# partner                              0.783168    0.470130    0.463366
# promo_friends                        0.574257    0.306494    0.079208
# phone                                1.000000    0.000000    1.000000
# contract_period                     10.889109    4.787013    2.352475
# group_visits                         0.542574    0.425974    0.215842
# age                                 29.982178   29.301299   28.477228
# avg_additional_charges_total       160.761016  143.957664  135.457501
# month_to_end_contract                9.954455    4.475325    2.198020
# lifetime                             4.736634    3.924675    2.809901
# avg_class_frequency_total            1.982055    1.847220    1.660461
# ...

# %% [markdown]
# **Plot distributions of features for the clusters. Do you notice anything?**

# %%
# define the function for rendering graphs of paired features for the clusters
def show_clusters_on_plot(df, x_name,y_name, cluster_name):
    plt.figure(figsize = (10,10))
    sns.scatterplot(df[x_name], df[y_name],
          hue = df[cluster_name], palette = 'Paired'
       )
    plt.title('{} vs {}'.format(x_name, y_name))
    plt.show()

# %%
# render the graph for the paired "avg_class_frequency_total" and "avg_class_frequency_current_month" features
show_clusters_on_plot(data, 'avg_class_frequency_total','avg_class_frequency_current_month','cluster')

# %%
# render the graph for the paired "avg_additional_charges_total" and "avg_class_frequency_current_month" features
show_clusters_on_plot(data, 'avg_additional_charges_total','avg_class_frequency_current_month','cluster')

# %%
# Features with respect to clusters
sns.displot(data= data, x= 'gender', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'near_location', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'partner', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'promo_friends', hue = 'cluster', kind = 'kde', legend = True)
sns.displot(data= data, x= 'phone', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'contract_period', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'group_visits', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'age', hue = 'cluster', kind = 'kde', legend = True)
sns.displot(data= data, x= 'avg_additional_charges_total', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'month_to_end_contract', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'lifetime', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'avg_class_frequency_total', hue = 'cluster', kind = 'kde', legend = True)
sns.displot(data= data, x= 'avg_class_frequency_current_month', hue = 'cluster', kind = 'kde', palette = 'Paired', legend = True)
sns.displot(data= data, x= 'churn', hue = 'cluster', kind = 'kde', legend = True)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# One feature-one graph. It help us ro see problems in clusters.
# </div>

# %% [markdown]
# **Calculate the churn rate for each cluster (use the groupby() method). Do they differ in terms of churn rate? Which clusters are prone to leaving, and which are loyal?**

# %%
data.groupby(['cluster'])['churn'].value_counts(normalize = True)
# Out:
# cluster  churn
# 0        0        0.972277
#          1        0.027723
# 1        0        0.732468
#          1        0.267532
# 2        0        0.556436
#          1        0.443564
# 3        1        0.514263
#          0        0.485737
# 4        0        0.931981
#          1        0.068019
# Name: churn, dtype: float64

# %% [markdown]
# **Conclusion**
#
#
# * In cluster 2 no body comes from the near location.
# * In cluster 3 all customers either live or work near the gym place.
# * Cluster 0 are the highest customers who come from the partners.
# * Almost all customers provide their phone number except customers in cluster 1.
# * Cluster 0 has the highest attendance rate in group visits than the others.
# * Cluster 0 and 4 have the highest lifetime.
# * Cluster 0 has the highest contract period  where as cluster 3 has the lowest.
# * The cluster that has the highest month to month contract is cluster 0.
# * Cluster 0 has the lowest churn rate where as cluster 3 has the highest.

# %% [markdown]
# # Step 5. Come up with conclusions and basic recommendations on working with customers

# %% [markdown]
# Draw conclusions and formulate recommendations regarding the strategy for customer interaction and retention.

# %% [markdown]
# You don't need to go into detail. Three or four essential principles and examples of their implementation in the form of specific marketing steps will do.

# %% [markdown]
# * There are 14 columns and 4000 rows of DataFrame.
# * There are no missing values.
# * There are no duplicates in the DataFrame.
# * Almost equal number of Mans and Womans.
# * The averae age of the customers is around 29.12 years.
# * The minimum and maximum age of the ustomers are 18 and 41 years respectively.
# * 48.68%, almost half of the gym are employees of a partner company who have discont program.
# * 84.53% of the gym customers live or work in the neighborhood of the gym.
# * 30.85% of the customers originally signed up through a "bring a friend" offer.
# * 90.4% of the customers provided their phone numbers.
# * The average contract period of customers is 4.68 months.
# * 41.22% of the customers takes part in group sessions.
# * The average lifetime of customers is 3.7 months.
# * Average frequency of visits per week over the customer's lifetime 1.86.
# * Average frequency of visits per week over the preceding month is 1.76.
# * The total amount of money spent on other gym services: cafe, athletic goods, cosmetics, massages, etc. is 146.94 dollars
# * The fact of churn for the month in question is 26.5%
# * The total customers in the gym are 4000, out of these 2939 will stay in the gym where as 1061 will leave the gym.
# * The average of genders in who will stay and leave the gym are equal.
# * Customers who live or work close to the gym are less likely to churn.
# * Customers of gym from the partner companies are less likely to churn than the others.
# * Customers of the gym who signed up under the “bring a friend” offer are less likely to churn.
# * Equal number of customers from those who churn and not churn provide their phone number.
# * The contract period for those who would prefer to stay in the gym is 5.75 months where as for those who churn is 1.72 months.
# * More users from those who stay in the gym take part in group session than those who churn, may be because they live and work close to the gmy.
# * The average age of users from those who stay is 29.97 years where as those who churn is 26.99 years.
# * The average total amount of money spent on other gym services: cafe, athletic goods, cosmetics, massages, etc. is more for those who stay in the gym than those who churn.
# * The lifetime for those who stay is 4.71 months where as for those who will churn is 0.99 months.
# * The average frequency of visits per week over the customer's lifetime and the average frequency of visits per week over the preceding month is more than double for who stay than for those who leave or churn.
# * 73% of the customers stay in the gym where as 27% those who will churn.73%
# * The number of customers who left and stay in the gym are 1061 and 2939 respectively.
# * With respect to gender 51% will stay and 49% will leave the gym.
# * With respect to near location 84.5% will stay and 15.5% will leave the gym.
# * With respect to partner 51.3% will stay and 48.7% will leave the gym.
# * With respect to promo friends 69.2% will stay and 30.8% will leave the gym.
# * With respect to phone 90.4% will stay and 9.6% will leave the gym.
# * With respect to group visits 58.8% will stay and 41.2% will leave the gym.
# * With respect to charn 73.5% will stay and 26.5% will leave the gym.
# * The correlation matrix shows that there is strong correlation between the 'contract period' and 'month to end contract' features as well as between 'avg_class_frequency_total' and 'avg_class_frequency_current_month' features.
# * The correlation matrix also shows that there is weak correlation of features with 'gender' and 'phone'.
# * As it is seen from the result, even though both models provide almost similar metric score, but logistic regression performed a little bit better result in precision and recall metric scores than random forest.
# * In cluster 2 no body comes from the near location.
# * In cluster 3 all customers either live or work near the gym place.
# * Cluster 0 are the highest customers who come from the partners.
# * Almost all customers provide their phone number except customers in cluster 1.
# * Cluster 0 has the highest attendance rate in group visits than the others.
# * Cluster 0 and 4 have the highest lifetime.
# * Cluster 0 has the highest contract period where as cluster 3 has the lowest.
# * The cluster that has the highest month to month contract is cluster 0.
# * Cluster 0 has the lowest churn rate where as cluster 3 has the highest that is cluster 0 are loyal to the gym..

# %% [markdown]
# * Customers or clients loyal to the gym are
#     * those who got discount from the partner companies.
#     * those who participate in group sessions.
#     * those who originally signed up through a "bring a friend".
#     * who have long  lifetime.
#     * who have long time contract period.
#     * live or work near the gym place.
#     * those who buy additional service.
#     * those who visit the gym frequently.
#
#
#
# From the above points, it can be recommended the gym
#
#   * Should make strong relationship with the nearby companies and give them additional discount in order the remaining employees to be motivated.
#   * should give discount for those who participate in group session as well as create a ground of competation amoung groups.
#   * should give additional discount for those who make contract for a long time, for example charge them only for 5 months if they register for 6 months that means give them 1 month free.
#   * should give bonus for those who bring their friends.
#   * should remind customers at least before one month before they leave.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Please, do not forget to add changes.
# </div>
